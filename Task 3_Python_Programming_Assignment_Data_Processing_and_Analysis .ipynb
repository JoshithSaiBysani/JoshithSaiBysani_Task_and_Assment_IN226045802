# %% [markdown]
# ### Problem Statement 1: Employee Performance Bonus Eligibility
# #### Description:
# - A company evaluates employee performance scores at the end of the year. You are given a dictionary containing employee names and their performance scores.
# #### Requirements:
# - Identify the highest performance score.
# - Handle ties if multiple employees have the same highest score.
# - Display all employees eligible for the top performance bonus.

# %%
employees = {}
n = int(input("Enter the number of items in dictionary"))
for i in range(n):
    name = input("Enter employee name")
    score = int(input("Enter employee score"))
    employees[name] = score
max_score = max(employees.values())
top_scorers = []
for name, score in employees.items():
    if score == max_score:
        top_scorers.append(name)
print("Top Performers Eligible for Bonus:",", ".join(top_scorers), "(Score:",max_score,")")
# Out:
# Enter the number of items in dictionary 4
# Enter employee name Ravi
# Enter employee score 92
# Enter employee name Anita
# Enter employee score 88
# Enter employee name Kiran
# Enter employee score 92
# Enter employee name Suresh
# Enter employee score 85
# Top Performers Eligible for Bonus: Ravi , Kiran (Score: 92 )

# %% [markdown]
# ### Problem Statement 2: Search Query Keyword Analysis
# #### Description:
# - An e-commerce website stores customer search queries. You are given a search query sentence entered by a user.
# #### Requirements:
# - Convert the input to lowercase.
# - Ignore common punctuation.
# - Count the frequency of each keyword.
# - Display only keywords searched more than once.

# %%
sentence = input("Enter a sentence")
lower_case = sentence.lower() # Convert the input to lowercase.
freq = {}
for word in lower_case.split(): # split() to get each word
    if word in freq:
        freq[word] += 1
    else:
        freq[word] = 1
result = {word: count for word, count in freq.items() if count > 1}
print(result)
# Out:
# Enter a sentence Buy mobile phone buy phone online
# {'buy': 2, 'phone': 2}

# %% [markdown]
# ### Problem Statement 3: Sensor Data Validation
# #### Description:
# - A factory collects sensor readings every hour. Each reading is stored in a list where the index represents the hour and the value represents the sensor reading.
# #### Requirements:
# - Identify readings that are even numbers (valid readings).
# - Store them as (hour_index, reading_value) pairs.
# - Ignore odd readings (invalid readings).

# %%
sensor_readings = list(map(int, input("Enter readings").split()))
ans = []
for index, reading in enumerate(sensor_readings): # enumerate() to access both index and value
    if reading % 2 == 0:
        ans.append((index, reading))
ans
# Out:
# Enter readings 3 4 7 8 10 12 5
# [(1, 4), (3, 8), (4, 10), (5, 12)]

# %% [markdown]
# ### Problem Statement 4: Email Domain Usage Analysis
# #### Description:
# - A company wants to analyze which email providers its users are using. You are given a list of employee email IDs.
# #### Requirements:
# - Count how many users belong to each email domain.
# - Calculate the percentage usage of each domain.

# %%
emails = list(map(str, input("Enter emails").split()))
email_freq = {}
for email in emails:
    domain = email.split('@')[1]
    email_freq[domain] = email_freq.get(domain, 0) + 1
for domain, freq in email_freq.items():
    percent = (freq / len(emails)) * 100
    print(domain,":",percent,"%")
# Out:
# Enter emails ravi@gmail.com anita@yahoo.com kiran@gmail.com suresh@gmail.com meena@yahoo.com
# gmail.com : 60.0 %
# yahoo.com : 40.0 %

# %% [markdown]
# ### Problem Statement 5: Sales Spike Detection
# #### Description:
# - A retail company tracks daily sales. Sudden spikes in sales may indicate promotions or unusual activity.
# #### Requirements:
# - Calculate the average daily sales.
# - Detect days where sales are more than 30% above average.
# - Display the day number and sale value.

# %%
sales = list(map(int, input("Enter the sales").split()))
avg_sales = sum(sales) / len(sales)
threshold = 1.3*avg_sales
for day, sale in enumerate(sales):
    if sale > threshold:
        print("Day",day+1,":",sale, end="\n")
# Out:
# Enter the sales 1200 1500 900 2200 1400 3000
# Day 6 : 3000

# %% [markdown]
# ### Problem Statement 6: Duplicate User ID Detection
# #### Description:
# - A system stores user IDs during registration. Duplicate IDs can cause data integrity issues.
# #### Requirements:
# - Identify duplicate user IDs.
# - Display how many times each duplicate appears.

# %%
user_ids = list(map(str, input("Enter user ids").split()))
freq = {}
for user in user_ids:
    freq[user] = freq.get(user, 0) + 1
for user, count in freq.items():
    if count > 1:
        print(user,"->",count,"times")
# Out:
# Enter user ids user1 user2 user3 user1 user3 user1
# user1 -> 3 times
# user3 -> 2 times
